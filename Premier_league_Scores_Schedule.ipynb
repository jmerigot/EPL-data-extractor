# %%
import requests
import json
import pandas as pd
import numpy as np
import bs4

# %% [markdown]
# # Premier League Football Matches' scores and Matches' schedule Data Extraction
# Extracting all information and match statistics from the One Football website, whic can be found here : https://onefootball.com/en/home
# We are focusing on the Premier League during the season 2023-2024, for sport betting purpose, the most relevant information are the current league ranking and the matches' results of the ongoing season.
# The following notebook scraps these data using mainly BeautifulSoup package, some attempts to use Selenium have been made to interact with JavaScript elements but ended in failure. We have adopted some less subtule and clean methods but we achieved the main objective of this notebook.

# %%
import re
import time
from bs4 import BeautifulSoup
import datetime

def get_teams_links(base_url):
    response = requests.get(base_url)
    team_links = []
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        team_link_tags = soup.find_all('a', class_='Standing_standings__rowGrid__45OOd')

        for tag in team_link_tags:
            team_name_tag = tag.find('p', class_='Standing_standings__teamName__psv61')
            if team_name_tag:
                team_links.append(tag['href'])

        return team_links
    else:
        return None


def get_match(base_url , id_match):
  """
  Get relevant informations about a match.
  Discriminate based on past and future match.
  """
  res = {}
  rep = requests.get(base_url + id_match)
  if rep.status_code == 200:
    #print("id match : ", id_match)

    soup = BeautifulSoup(rep.text, "html.parser")



    if not "vs" in soup.title.text:
      return None

    league = soup.find("span", class_="title-7-medium MatchScoreCompetition_competitionName__wONrf")
    if league is None or league.text != "Premier League":
      return None

    s = soup.title.text.split("vs")

    team_home = s[0]
    res["team_home"] = team_home
    match = re.match(r'^(.*?)(?=\|)', s[1])
    if match:
        team_away = match.group(1)
        res["team_away"] = team_away
    else:
        print("Pattern not found in the string.")
    res["onefootball_link"] = base_url + id_match

    info = soup.find_all("span", class_="title-8-regular MatchInfoEntry_subtitle__Mb7Jd")
    res["datetime"] = info[1].text
    res["location"] = info[2].text
    date = datetime.datetime.strptime(str(res["datetime"]), "%d/%m/%Y")

    print(team_home , " vs ", team_away, " ", str(res["datetime"]))

    if date > datetime.datetime.now():
      return pd.DataFrame(res, index=[0])
    else :
      s = soup.find("p",class_="MatchScore_scores__Hnn5f title-2-bold") #get the score
      if s is None:
        return None
      else:
        s = s.text
        score_home , score_away = s.split(":")

        res["score_home"] = score_home
        res["score_away"] = score_away

        preds = soup.find_all("li", class_="MatchPrediction_buttonsElement__EDqZN") #get the match predictions given before the match
        probas = ["home_win_proba", "draw_proba","away_win_proba"]

        if preds is not None:
          for i, s in enumerate(preds):
            res[probas[i]] = s.text

        list_elements = ["possession","total_shots","shots_on_target","duels_won"]
        for k, t in enumerate(soup.find_all('p', class_= lambda x: x and 'Entry_home' in x)):
          res["home_" + list_elements[k]] = t.text
        for k, t in enumerate(soup.find_all('p', class_= lambda x: x and 'Entry_away' in x)):
          res["away_" + list_elements[k]] = t.text

        return pd.DataFrame(res, index=[0])
  else:
    return None

# %%
list_results = []
list_future_matches = []
match_id = 2390326  #first match of the 2023-2024 Premier League Season

base_url = "https://onefootball.com/en/match/"
cpt=0

while cpt < 10:
  time.sleep(0.1)
  df = get_match(base_url, str(match_id))
  if df is not None:
    cpt = 0
    if not "score_home" in df.columns:
      list_future_matches.append(df)
    else:
      list_results.append(df)
  else:
    cpt+=1

  match_id +=1

if len(list_results) > 0 :
  table_past_matches = pd.concat(list_results, ignore_index=True)
if len(list_future_matches)> 0:
  table_future_matches =  pd.concat(list_future_matches, ignore_index=True)
# Out:
# Burnley   vs   Manchester City    11/08/2023
# Arsenal   vs   Nottingham Forest    12/08/2023
# AFC Bournemouth   vs   West Ham United    12/08/2023
# Brighton & Hove Albion   vs   Luton Town    12/08/2023
# Everton   vs   Fulham    12/08/2023
# Newcastle United   vs   Aston Villa    12/08/2023
# Sheffield United   vs   Crystal Palace    12/08/2023
# Brentford   vs   Tottenham Hotspur    13/08/2023
# Chelsea   vs   Liverpool    13/08/2023
# Manchester United   vs   Wolverhampton Wanderers    14/08/2023
# Aston Villa   vs   Everton    20/08/2023
# Crystal Palace   vs   Arsenal    21/08/2023
# Fulham   vs   Brentford    19/08/2023
# Liverpool   vs   AFC Bournemouth    19/08/2023
# Luton Town   vs   Burnley    03/10/2023
# Manchester City   vs   Newcastle United    19/08/2023
# Nottingham Forest   vs   Sheffield United    18/08/2023
# Tottenham Hotspur   vs   Manchester United    19/08/2023
# West Ham United   vs   Chelsea    20/08/2023
# Wolverhampton Wanderers   vs   Brighton & Hove Albion    19/08/2023
# Arsenal   vs   Fulham    26/08/2023
# AFC Bournemouth   vs   Tottenham Hotspur    26/08/2023
# Brentford   vs   Crystal Palace    26/08/2023
# Brighton & Hove Albion   vs   West Ham United    26/08/2023
# Burnley   vs   Aston Villa    27/08/2023
# Chelsea   vs   Luton Town    25/08/2023
# Everton   vs   Wolverhampton Wanderers    26/08/2023
# Manchester United   vs   Nottingham Forest    26/08/2023
# Newcastle United   vs   Liverpool    27/08/2023
# Sheffield United   vs   Manchester City    27/08/2023
# Arsenal   vs   Manchester United    03/09/2023
# Brentford   vs   AFC Bournemouth    02/09/2023
# Brighton & Hove Albion   vs   Newcastle United    02/09/2023
# Burnley   vs   Tottenham Hotspur    02/09/2023
# Chelsea   vs   Nottingham Forest    02/09/2023
# Crystal Palace   vs   Wolverhampton Wanderers    03/09/2023
# Liverpool   vs   Aston Villa    03/09/2023
# Luton Town   vs   West Ham United    01/09/2023
# Manchester City   vs   Fulham    02/09/2023
# Sheffield United   vs   Everton    02/09/2023
# Aston Villa   vs   Crystal Palace    16/09/2023
# AFC Bournemouth   vs   Chelsea    17/09/2023
# Everton   vs   Arsenal    17/09/2023
# Fulham   vs   Luton Town    16/09/2023
# Manchester United   vs   Brighton & Hove Albion    16/09/2023
# Newcastle United   vs   Brentford    16/09/2023
# Nottingham Forest   vs   Burnley    18/09/2023
# Tottenham Hotspur   vs   Sheffield United    16/09/2023
# West Ham United   vs   Manchester City    16/09/2023
# Wolverhampton Wanderers   vs   Liverpool    16/09/2023
# Arsenal   vs   Tottenham Hotspur    24/09/2023
# Brentford   vs   Everton    23/09/2023
# Brighton & Hove Albion   vs   AFC Bournemouth    24/09/2023
# Burnley   vs   Manchester United    23/09/2023
# Chelsea   vs   Aston Villa    24/09/2023
# Crystal Palace   vs   Fulham    23/09/2023
# Liverpool   vs   West Ham United    24/09/2023
# Luton Town   vs   Wolverhampton Wanderers    23/09/2023
# Manchester City   vs   Nottingham Forest    23/09/2023
# Sheffield United   vs   Newcastle United    24/09/2023
# Aston Villa   vs   Brighton & Hove Albion    30/09/2023
# AFC Bournemouth   vs   Arsenal    30/09/2023
# Everton   vs   Luton Town    30/09/2023
# Fulham   vs   Chelsea    02/10/2023
# Manchester United   vs   Crystal Palace    30/09/2023
# Newcastle United   vs   Burnley    30/09/2023
# Nottingham Forest   vs   Brentford    01/10/2023
# Tottenham Hotspur   vs   Liverpool    30/09/2023
# West Ham United   vs   Sheffield United    30/09/2023
# Wolverhampton Wanderers   vs   Manchester City    30/09/2023
# Arsenal   vs   Manchester City    08/10/2023
# Brighton & Hove Albion   vs   Liverpool    08/10/2023
# Burnley   vs   Chelsea    07/10/2023
# Crystal Palace   vs   Nottingham Forest    07/10/2023
# Everton   vs   AFC Bournemouth    07/10/2023
# Fulham   vs   Sheffield United    07/10/2023
# Luton Town   vs   Tottenham Hotspur    07/10/2023
# Manchester United   vs   Brentford    07/10/2023
# West Ham United   vs   Newcastle United    08/10/2023
# Wolverhampton Wanderers   vs   Aston Villa    08/10/2023
# Aston Villa   vs   West Ham United    22/10/2023
# AFC Bournemouth   vs   Wolverhampton Wanderers    21/10/2023
# Brentford   vs   Burnley    21/10/2023
# Chelsea   vs   Arsenal    21/10/2023
# Liverpool   vs   Everton    21/10/2023
# Manchester City   vs   Brighton & Hove Albion    21/10/2023
# Newcastle United   vs   Crystal Palace    21/10/2023
# Nottingham Forest   vs   Luton Town    21/10/2023
# Sheffield United   vs   Manchester United    21/10/2023
# Tottenham Hotspur   vs   Fulham    23/10/2023
# Arsenal   vs   Sheffield United    28/10/2023
# Aston Villa   vs   Luton Town    29/10/2023
# AFC Bournemouth   vs   Burnley    28/10/2023
# Brighton & Hove Albion   vs   Fulham    29/10/2023
# Chelsea   vs   Brentford    28/10/2023
# Crystal Palace   vs   Tottenham Hotspur    27/10/2023
# Liverpool   vs   Nottingham Forest    29/10/2023
# Manchester United   vs   Manchester City    29/10/2023
# West Ham United   vs   Everton    29/10/2023
# Wolverhampton Wanderers   vs   Newcastle United    28/10/2023
# Brentford   vs   West Ham United    04/11/2023
# Burnley   vs   Crystal Palace    04/11/2023
# Everton   vs   Brighton & Hove Albion    04/11/2023
# Fulham   vs   Manchester United    04/11/2023
# Luton Town   vs   Liverpool    05/11/2023
# Manchester City   vs   AFC Bournemouth    04/11/2023
# Newcastle United   vs   Arsenal    04/11/2023
# Nottingham Forest   vs   Aston Villa    05/11/2023
# Sheffield United   vs   Wolverhampton Wanderers    04/11/2023
# Tottenham Hotspur   vs   Chelsea    06/11/2023
# Arsenal   vs   Burnley    11/11/2023
# Aston Villa   vs   Fulham    12/11/2023
# AFC Bournemouth   vs   Newcastle United    11/11/2023
# Brighton & Hove Albion   vs   Sheffield United    12/11/2023
# Chelsea   vs   Manchester City    12/11/2023
# Crystal Palace   vs   Everton    11/11/2023
# Liverpool   vs   Brentford    12/11/2023
# Manchester United   vs   Luton Town    11/11/2023
# West Ham United   vs   Nottingham Forest    12/11/2023
# Wolverhampton Wanderers   vs   Tottenham Hotspur    11/11/2023
# Brentford   vs   Arsenal    25/11/2023
# Burnley   vs   West Ham United    25/11/2023
# Everton   vs   Manchester United    26/11/2023
# Fulham   vs   Wolverhampton Wanderers    27/11/2023
# Luton Town   vs   Crystal Palace    25/11/2023
# Manchester City   vs   Liverpool    25/11/2023
# Newcastle United   vs   Chelsea    25/11/2023
# Nottingham Forest   vs   Brighton & Hove Albion    25/11/2023
# Sheffield United   vs   AFC Bournemouth    25/11/2023
# Tottenham Hotspur   vs   Aston Villa    26/11/2023
# Arsenal   vs   Wolverhampton Wanderers    02/12/2023
# AFC Bournemouth   vs   Aston Villa    03/12/2023
# Brentford   vs   Luton Town    02/12/2023
# Burnley   vs   Sheffield United    02/12/2023
# Chelsea   vs   Brighton & Hove Albion    03/12/2023
# Liverpool   vs   Fulham    03/12/2023
# Manchester City   vs   Tottenham Hotspur    03/12/2023
# Newcastle United   vs   Manchester United    02/12/2023
# Nottingham Forest   vs   Everton    02/12/2023
# West Ham United   vs   Crystal Palace    03/12/2023
# Aston Villa   vs   Manchester City    06/12/2023
# Brighton & Hove Albion   vs   Brentford    06/12/2023
# Crystal Palace   vs   AFC Bournemouth    06/12/2023
# Everton   vs   Newcastle United    07/12/2023
# Fulham   vs   Nottingham Forest    06/12/2023
# Luton Town   vs   Arsenal    05/12/2023
# Sheffield United   vs   Liverpool    06/12/2023
# Tottenham Hotspur   vs   West Ham United    07/12/2023
# Wolverhampton Wanderers   vs   Burnley    05/12/2023
# Manchester United   vs   Chelsea    06/12/2023
# Aston Villa   vs   Arsenal    09/12/2023
# Brighton & Hove Albion   vs   Burnley    09/12/2023
# Crystal Palace   vs   Liverpool    09/12/2023
# Everton   vs   Chelsea    10/12/2023
# Fulham   vs   West Ham United    10/12/2023
# Luton Town   vs   Manchester City    10/12/2023
# Manchester United   vs   AFC Bournemouth    09/12/2023
# Sheffield United   vs   Brentford    09/12/2023
# Tottenham Hotspur   vs   Newcastle United    10/12/2023
# Wolverhampton Wanderers   vs   Nottingham Forest    09/12/2023
# Arsenal   vs   Brighton & Hove Albion    17/12/2023
# AFC Bournemouth   vs   Luton Town    18/05/2024
# Brentford   vs   Aston Villa    17/12/2023
# Burnley   vs   Everton    16/12/2023
# Chelsea   vs   Sheffield United    16/12/2023
# Liverpool   vs   Manchester United    17/12/2023
# Manchester City   vs   Crystal Palace    16/12/2023
# Newcastle United   vs   Fulham    16/12/2023
# Nottingham Forest   vs   Tottenham Hotspur    15/12/2023
# West Ham United   vs   Wolverhampton Wanderers    17/12/2023
# Aston Villa   vs   Sheffield United    22/12/2023
# Crystal Palace   vs   Brighton & Hove Albion    21/12/2023
# Fulham   vs   Burnley    23/12/2023
# Liverpool   vs   Arsenal    23/12/2023
# Luton Town   vs   Newcastle United    23/12/2023
# Manchester City   vs   Brentford    23/12/2023
# Nottingham Forest   vs   AFC Bournemouth    23/12/2023
# Tottenham Hotspur   vs   Everton    23/12/2023
# West Ham United   vs   Manchester United    23/12/2023
# Wolverhampton Wanderers   vs   Chelsea    24/12/2023
# Arsenal   vs   West Ham United    28/12/2023
# AFC Bournemouth   vs   Fulham    26/12/2023
# Brentford   vs   Wolverhampton Wanderers    27/12/2023
# Brighton & Hove Albion   vs   Tottenham Hotspur    28/12/2023
# Burnley   vs   Liverpool    26/12/2023
# Chelsea   vs   Crystal Palace    27/12/2023
# Everton   vs   Manchester City    27/12/2023
# Manchester United   vs   Aston Villa    26/12/2023
# Newcastle United   vs   Nottingham Forest    26/12/2023
# Sheffield United   vs   Luton Town    26/12/2023
# Aston Villa   vs   Burnley    30/12/2023
# Crystal Palace   vs   Brentford    30/12/2023
# Fulham   vs   Arsenal    31/12/2023
# Liverpool   vs   Newcastle United    01/01/2024
# Luton Town   vs   Chelsea    30/12/2023
# Manchester City   vs   Sheffield United    30/12/2023
# Nottingham Forest   vs   Manchester United    30/12/2023
# Tottenham Hotspur   vs   AFC Bournemouth    31/12/2023
# West Ham United   vs   Brighton & Hove Albion    02/01/2024
# Wolverhampton Wanderers   vs   Everton    30/12/2023
# Arsenal   vs   Crystal Palace    20/01/2024
# AFC Bournemouth   vs   Liverpool    21/01/2024
# Brentford   vs   Nottingham Forest    20/01/2024
# Brighton & Hove Albion   vs   Wolverhampton Wanderers    22/01/2024
# Burnley   vs   Luton Town    15/01/2024
# Chelsea   vs   Fulham    13/01/2024
# Everton   vs   Aston Villa    14/01/2024
# Manchester United   vs   Tottenham Hotspur    14/01/2024
# Newcastle United   vs   Manchester City    13/01/2024
# Sheffield United   vs   West Ham United    21/01/2024
# Aston Villa   vs   Newcastle United    30/01/2024
# Crystal Palace   vs   Sheffield United    30/01/2024
# Fulham   vs   Everton    30/01/2024
# Luton Town   vs   Brighton & Hove Albion    30/01/2024
# Nottingham Forest   vs   Arsenal    30/01/2024
# Tottenham Hotspur   vs   Brentford    31/01/2024
# West Ham United   vs   AFC Bournemouth    01/02/2024
# Wolverhampton Wanderers   vs   Manchester United    01/02/2024
# Liverpool   vs   Chelsea    31/01/2024
# Manchester City   vs   Burnley    31/01/2024
# Arsenal   vs   Liverpool    04/02/2024
# AFC Bournemouth   vs   Nottingham Forest    04/02/2024
# Brentford   vs   Manchester City    05/02/2024
# Brighton & Hove Albion   vs   Crystal Palace    03/02/2024
# Burnley   vs   Fulham    03/02/2024
# Chelsea   vs   Wolverhampton Wanderers    04/02/2024
# Everton   vs   Tottenham Hotspur    03/02/2024
# Manchester United   vs   West Ham United    04/02/2024
# Newcastle United   vs   Luton Town    03/02/2024
# Sheffield United   vs   Aston Villa    03/02/2024
# Aston Villa   vs   Manchester United    11/02/2024
# Crystal Palace   vs   Chelsea    12/02/2024
# Fulham   vs   AFC Bournemouth    10/02/2024
# Liverpool   vs   Burnley    10/02/2024
# Luton Town   vs   Sheffield United    10/02/2024
# Manchester City   vs   Everton    10/02/2024
# Nottingham Forest   vs   Newcastle United    10/02/2024
# Tottenham Hotspur   vs   Brighton & Hove Albion    10/02/2024
# West Ham United   vs   Arsenal    11/02/2024
# Wolverhampton Wanderers   vs   Brentford    10/02/2024
# Brentford   vs   Liverpool    17/02/2024
# Burnley   vs   Arsenal    17/02/2024
# Everton   vs   Crystal Palace    19/02/2024
# Fulham   vs   Aston Villa    17/02/2024
# Luton Town   vs   Manchester United    18/02/2024
# Manchester City   vs   Chelsea    17/02/2024
# Newcastle United   vs   AFC Bournemouth    17/02/2024
# Nottingham Forest   vs   West Ham United    17/02/2024
# Sheffield United   vs   Brighton & Hove Albion    18/02/2024
# Tottenham Hotspur   vs   Wolverhampton Wanderers    17/02/2024
# Arsenal   vs   Newcastle United    24/02/2024
# Aston Villa   vs   Nottingham Forest    24/02/2024
# AFC Bournemouth   vs   Manchester City    24/02/2024
# Brighton & Hove Albion   vs   Everton    24/02/2024
# Chelsea   vs   Tottenham Hotspur    23/02/2024
# Crystal Palace   vs   Burnley    24/02/2024
# Liverpool   vs   Luton Town    24/02/2024
# Manchester United   vs   Fulham    24/02/2024
# West Ham United   vs   Brentford    26/02/2024
# Wolverhampton Wanderers   vs   Sheffield United    25/02/2024
# Brentford   vs   Chelsea    02/03/2024
# Burnley   vs   AFC Bournemouth    02/03/2024
# Everton   vs   West Ham United    02/03/2024
# Fulham   vs   Brighton & Hove Albion    02/03/2024
# Luton Town   vs   Aston Villa    02/03/2024
# Manchester City   vs   Manchester United    02/03/2024
# Newcastle United   vs   Wolverhampton Wanderers    02/03/2024
# Nottingham Forest   vs   Liverpool    02/03/2024
# Sheffield United   vs   Arsenal    02/03/2024
# Tottenham Hotspur   vs   Crystal Palace    02/03/2024
# Arsenal   vs   Brentford    09/03/2024
# Aston Villa   vs   Tottenham Hotspur    09/03/2024
# AFC Bournemouth   vs   Sheffield United    09/03/2024
# Brighton & Hove Albion   vs   Nottingham Forest    09/03/2024
# Chelsea   vs   Newcastle United    09/03/2024
# Crystal Palace   vs   Luton Town    09/03/2024
# Liverpool   vs   Manchester City    09/03/2024
# Manchester United   vs   Everton    09/03/2024
# West Ham United   vs   Burnley    09/03/2024
# Wolverhampton Wanderers   vs   Fulham    09/03/2024
# Arsenal   vs   Chelsea    16/03/2024
# Brighton & Hove Albion   vs   Manchester City    16/03/2024
# Burnley   vs   Brentford    16/03/2024
# Crystal Palace   vs   Newcastle United    16/03/2024
# Everton   vs   Liverpool    16/03/2024
# Fulham   vs   Tottenham Hotspur    16/03/2024
# Luton Town   vs   Nottingham Forest    16/03/2024
# Manchester United   vs   Sheffield United    16/03/2024
# West Ham United   vs   Aston Villa    16/03/2024
# Wolverhampton Wanderers   vs   AFC Bournemouth    16/03/2024
# Aston Villa   vs   Wolverhampton Wanderers    30/03/2024
# AFC Bournemouth   vs   Everton    30/03/2024
# Brentford   vs   Manchester United    30/03/2024
# Chelsea   vs   Burnley    30/03/2024
# Liverpool   vs   Brighton & Hove Albion    30/03/2024
# Manchester City   vs   Arsenal    30/03/2024
# Newcastle United   vs   West Ham United    30/03/2024
# Nottingham Forest   vs   Crystal Palace    30/03/2024
# Sheffield United   vs   Fulham    30/03/2024
# Tottenham Hotspur   vs   Luton Town    30/03/2024
# Arsenal   vs   Luton Town    02/04/2024
# AFC Bournemouth   vs   Crystal Palace    02/04/2024
# Brentford   vs   Brighton & Hove Albion    02/04/2024
# Burnley   vs   Wolverhampton Wanderers    02/04/2024
# Nottingham Forest   vs   Fulham    02/04/2024
# West Ham United   vs   Tottenham Hotspur    02/04/2024
# Chelsea   vs   Manchester United    03/04/2024
# Liverpool   vs   Sheffield United    03/04/2024
# Manchester City   vs   Aston Villa    03/04/2024
# Newcastle United   vs   Everton    03/04/2024
# Aston Villa   vs   Brentford    06/04/2024
# Brighton & Hove Albion   vs   Arsenal    06/04/2024
# Crystal Palace   vs   Manchester City    06/04/2024
# Everton   vs   Burnley    06/04/2024
# Fulham   vs   Newcastle United    06/04/2024
# Luton Town   vs   AFC Bournemouth    06/04/2024
# Manchester United   vs   Liverpool    06/04/2024
# Sheffield United   vs   Chelsea    06/04/2024
# Tottenham Hotspur   vs   Nottingham Forest    06/04/2024
# Wolverhampton Wanderers   vs   West Ham United    06/04/2024
# Arsenal   vs   Aston Villa    13/04/2024
# AFC Bournemouth   vs   Manchester United    13/04/2024
# Brentford   vs   Sheffield United    13/04/2024
# Burnley   vs   Brighton & Hove Albion    13/04/2024
# Chelsea   vs   Everton    13/04/2024
# Liverpool   vs   Crystal Palace    13/04/2024
# Manchester City   vs   Luton Town    13/04/2024
# Newcastle United   vs   Tottenham Hotspur    13/04/2024
# Nottingham Forest   vs   Wolverhampton Wanderers    13/04/2024
# West Ham United   vs   Fulham    13/04/2024
# Aston Villa   vs   AFC Bournemouth    20/04/2024
# Brighton & Hove Albion   vs   Chelsea    20/04/2024
# Crystal Palace   vs   West Ham United    20/04/2024
# Everton   vs   Nottingham Forest    20/04/2024
# Fulham   vs   Liverpool    20/04/2024
# Luton Town   vs   Brentford    20/04/2024
# Manchester United   vs   Newcastle United    20/04/2024
# Sheffield United   vs   Burnley    20/04/2024
# Tottenham Hotspur   vs   Manchester City    20/04/2024
# Wolverhampton Wanderers   vs   Arsenal    20/04/2024
# Aston Villa   vs   Chelsea    27/04/2024
# AFC Bournemouth   vs   Brighton & Hove Albion    27/04/2024
# Everton   vs   Brentford    27/04/2024
# Fulham   vs   Crystal Palace    27/04/2024
# Manchester United   vs   Burnley    27/04/2024
# Newcastle United   vs   Sheffield United    27/04/2024
# Nottingham Forest   vs   Manchester City    27/04/2024
# Tottenham Hotspur   vs   Arsenal    27/04/2024
# West Ham United   vs   Liverpool    27/04/2024
# Wolverhampton Wanderers   vs   Luton Town    27/04/2024
# Arsenal   vs   AFC Bournemouth    04/05/2024
# Brentford   vs   Fulham    04/05/2024
# Brighton & Hove Albion   vs   Aston Villa    04/05/2024
# Burnley   vs   Newcastle United    04/05/2024
# Chelsea   vs   West Ham United    04/05/2024
# Crystal Palace   vs   Manchester United    04/05/2024
# Liverpool   vs   Tottenham Hotspur    04/05/2024
# Luton Town   vs   Everton    04/05/2024
# Manchester City   vs   Wolverhampton Wanderers    04/05/2024
# Sheffield United   vs   Nottingham Forest    04/05/2024
# Aston Villa   vs   Liverpool    11/05/2024
# AFC Bournemouth   vs   Brentford    11/05/2024
# Everton   vs   Sheffield United    11/05/2024
# Fulham   vs   Manchester City    11/05/2024
# Manchester United   vs   Arsenal    11/05/2024
# Newcastle United   vs   Brighton & Hove Albion    11/05/2024
# Nottingham Forest   vs   Chelsea    11/05/2024
# Tottenham Hotspur   vs   Burnley    11/05/2024
# West Ham United   vs   Luton Town    11/05/2024
# Wolverhampton Wanderers   vs   Crystal Palace    11/05/2024
# Arsenal   vs   Everton    19/05/2024
# Brentford   vs   Newcastle United    19/05/2024
# Brighton & Hove Albion   vs   Manchester United    19/05/2024
# Burnley   vs   Nottingham Forest    19/05/2024
# Chelsea   vs   AFC Bournemouth    19/05/2024
# Crystal Palace   vs   Aston Villa    19/05/2024
# Liverpool   vs   Wolverhampton Wanderers    19/05/2024
# Luton Town   vs   Fulham    19/05/2024
# Manchester City   vs   West Ham United    19/05/2024
# Sheffield United   vs   Tottenham Hotspur    19/05/2024

# %%
table_past_matches
# Out:
#                     team_home                 team_away  \
# 0                    Burnley           Manchester City
# 1                    Arsenal         Nottingham Forest
# 2            AFC Bournemouth           West Ham United
# 3     Brighton & Hove Albion                Luton Town
# 4                    Everton                    Fulham
# ..                        ...                       ...
# 193          Manchester City          Sheffield United
# 194        Nottingham Forest         Manchester United
# 195        Tottenham Hotspur           AFC Bournemouth
# 196          West Ham United    Brighton & Hove Albion
# 197  Wolverhampton Wanderers                   Everton
#
#                              onefootball_link    datetime  \
# 0    https://onefootball.com/en/match/2390326  11/08/2023
# 1    https://onefootball.com/en/match/2390327  12/08/2023
# 2    https://onefootball.com/en/match/2390328  12/08/2023
# 3    https://onefootball.com/en/match/2390329  12/08/2023
# 4    https://onefootball.com/en/match/2390330  12/08/2023
# ..                                        ...         ...
# 193  https://onefootball.com/en/match/2390521  30/12/2023
# 194  https://onefootball.com/en/match/2390522  30/12/2023
# 195  https://onefootball.com/en/match/2390523  31/12/2023
# 196  https://onefootball.com/en/match/2390524  02/01/2024
# 197  https://onefootball.com/en/match/2390525  30/12/2023
#
#                       location score_home score_away home_win_proba  \
# 0                    Turf Moor          0          3             0%
# 1             Emirates Stadium          2          1             0%
# 2             Vitality Stadium          1          1             0%
# 3                 Amex Stadium          4          1             0%
# 4                Goodison Park          0          1             0%
# ..                         ...        ...        ...            ...
# 193             Etihad Stadium          2          0            90%
# 194            The City Ground          2          1            21%
# 195  Tottenham Hotspur Stadium          3          1            82%
# 196             London Stadium          0          0            61%
# 197           Molineux Stadium          3          0            58%
#
#     draw_proba away_win_proba home_possession home_total_shots  \
# 0           0%             0%             34%                6
# 1           0%             0%             79%               15
# 2           0%             0%             63%               14
# 3           0%             0%             71%               27
# 4           0%             0%             40%               19
# ..         ...            ...             ...              ...
# 193         2%             8%             81%               18
# 194         3%            76%             45%                8
# 195         3%            15%             51%               12
# 196         7%            32%             31%                6
# 197         7%            35%             53%               12
#
#     home_shots_on_target home_duels_won away_possession away_total_shots  \
# 0                      1            45%             66%               17
# 1                      7            46%             21%                6
# 2                      5            41%             37%               16
# 3                     12            47%             29%                9
# 4                      9            46%             60%                9
# ..                   ...            ...             ...              ...
# 193                    4            49%             19%                4
# 194                    2            55%             55%               10
# 195                    6            50%             49%               24
# 196                    2            55%             69%               22
# 197                    6            51%             47%               10
#
#     away_shots_on_target away_duels_won
# 0                      8            55%
# 1                      2            54%
# 2                      3            59%
# 3                      3            53%
# 4                      2            55%
# ..                   ...            ...
# 193                    2            51%
# 194                    5            45%
# 195                    4            50%
# 196                    8            45%
# 197                    0            50%
#
# [198 rows x 18 columns]

# %%
table_past_matches.to_csv('premier_league_past_matches_' + datetime.datetime.now().strftime("%d_%m_%Y") + ".csv")
table_future_matches.to_csv('premier_league_future_matches_' + datetime.datetime.now().strftime("%d_%m_%Y") + ".csv")

# %% [markdown]
# ## Get the result table

# %%
def get_result_table():
  link = "https://onefootball.com/en/competition/premier-league-9/table"
  rep = requests.get(link)
  d = {"Rank": [], "Team":[], "Played":[], "Wins":[], "Draw":[],"Losses":[],"Goal_diff":[],"Points":[]}
  df = pd.DataFrame(d)
  if rep.status_code == 200:
    page = BeautifulSoup(rep.text, "html.parser")
    rankings = page.find_all("li", class_="Standing_standings__row__5sdZG Standing_standings__rowLink__Skr86")
    for pos , results in enumerate(rankings):
      team = results.find("a").get("aria-label")
      df.loc[len(df)] = [t.text for t in results.find_all("div") if t.text !='']

  df.set_index("Rank",inplace=True )
  return df

get_result_table()
# Out:
#                          Team Played Wins Draw Losses Goal_diff Points
# Rank
# 1                   Liverpool     20   13    6      1        25     45
# 2                 Aston Villa     20   13    3      4        16     42
# 3             Manchester City     19   12    4      3        24     40
# 4                     Arsenal     20   12    4      4        17     40
# 5           Tottenham Hotspur     20   12    3      5        13     39
# 6             West Ham United     20   10    4      6         3     34
# 7      Brighton & Hove Albion     20    8    7      5         5     31
# 8           Manchester United     20   10    1      9        -5     31
# 9            Newcastle United     20    9    2      9        10     29
# 10                    Chelsea     20    8    4      8         3     28
# 11    Wolverhampton Wanderers     20    8    4      8        -1     28
# 12            AFC Bournemouth     19    7    4      8        -7     25
# 13                     Fulham     20    7    3     10        -7     24
# 14             Crystal Palace     20    5    6      9        -7     21
# 15          Nottingham Forest     20    5    5     10       -11     20
# 16                  Brentford     19    5    4     10        -5     19
# 17                    Everton     20    8    2     10        -4     16
# 18                 Luton Town     19    4    3     12       -14     15
# 19                    Burnley     20    3    2     15       -21     11
# 20           Sheffield United     20    2    3     15       -34      9

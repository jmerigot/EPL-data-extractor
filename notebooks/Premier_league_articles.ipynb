# %%
import re
import time
from bs4 import BeautifulSoup
import datetime
import requests
import json
import pandas as pd
import numpy as np
import bs4

# %% [markdown]
# # Premier League Football news Data Extraction
# Since Premier League has always been a hot topic, dozens of articles are written every day about PL (scores, transfert, gossip and so on). We propose to aggregate PL related articles from two sources : https://onefootball.com/en/competition/premier-league-9 and https://www.bbc.com/sport/football/premier-league . We tried to scrap other website like eurosport.com but they were protected against scraping and crawling redirecting the get requests.

# %% [markdown]
# ### Articles from One Football

# %%
from lxml import html, etree

def get_news_link_onefootball(link):
  """
  extract news links from a web page
  """
  rep = requests.get(link)
  if rep.status_code == 200:
    soup = BeautifulSoup(rep.text, 'html.parser')
    """xml_doc = html.fromstring(rep.text)
    xpath_query = "//a[contains(@href,'news')]"
    matching_elements = xml_doc.xpath(xpath_query)
    news_links = [element.get('href') for element in matching_elements]
    return news_links"""
    pattern = r"^/en/news"
    web_links = soup.find_all('a', href=True)
    return set([web_link['href'] for web_link in web_links if re.search(pattern, str(web_link['href']))])


link = "https://onefootball.com/en/competition/premier-league-9"
get_news_link_onefootball(link)
# Out:
# {'/en/news/20-most-expensive-premier-league-transfers-ever-based-on-inflation-adjusted-fees-38825330',
#  '/en/news/40m-ace-has-been-watched-several-times-by-man-united-38825374',
#  '/en/news/arsenal-learn-the-asking-price-for-23-year-old-attacking-target-38825375',
#  '/en/news/liverpool-fan-favourite-has-been-offered-to-several-premier-league-clubs-38825312',
#  '/en/news/man-city-complete-their-first-transfer-deal-of-the-january-window-38825126',
#  '/en/news/man-united-are-keen-on-signing-the-next-moises-caicedo-38824982',
#  '/en/news/man-utd-told-to-be-relieved-to-get-5m-back-for-deadweight-whose-agent-deserves-a-slap-38825358',
#  '/en/news/tottenham-are-desperate-to-complete-the-signing-of-60m-striker-38825082',
#  '/en/news/van-de-beek-makes-tough-man-utd-admission-as-he-highlights-one-positive-from-horror-prem-spell-38825093',
#  '/en/news/why-jesse-lingard-still-doesnt-have-a-new-club-38825489'}

# %%
from collections import deque
def get_news_links_bfs(starting_url, website_path ,link_extractor = get_news_link_onefootball ,  visited_urls=None, max_nb = 5):
  """
  Implement a BFS to explore and retrieve article urls from onefootball.com
  """
  queue = deque([starting_url])
  visited_urls = set()
  level = 0
  cpt_old = len(visited_urls)
  cpt = 0
  while queue and len(visited_urls) < max_nb:
      url = queue.popleft()
      visited_urls.add(url)  # only visits the page
      links = link_extractor(url)  # get links, maybe parse the result of last statement
      if links is not None:
        for l in links:
          queue.append(website_path + l)
        if len(visited_urls)%10 == 0:
          print("nb visited articles : ", len(visited_urls))
        cpt_new = len(visited_urls)

      if cpt_new == cpt_old:
        cpt+=1
      else:
        cpt=0
        cpt_old = cpt_new
      if cpt == cpt_old:
        return visited_urls
  visited_urls.remove(starting_url)
  return visited_urls

# %%
list_articles = get_news_links_bfs(starting_url = "https://onefootball.com/en/competition/premier-league-9", website_path = "https://onefootball.com", link_extractor=get_news_link_onefootball, max_nb=1000)
# Out:
# nb visited articles :  10
# nb visited articles :  20
# nb visited articles :  20
# nb visited articles :  30
# nb visited articles :  30
# nb visited articles :  30
# nb visited articles :  40
# nb visited articles :  50
# nb visited articles :  50
# nb visited articles :  60
# nb visited articles :  60
# nb visited articles :  60
# nb visited articles :  60
# nb visited articles :  60
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  80
# nb visited articles :  80
# nb visited articles :  90
# nb visited articles :  90
# nb visited articles :  90

# %%
from datetime import datetime
import time
from tqdm import tqdm

def table_news_articles_one_football(list_links_articles):

  list_infos = []
  for i, link in tqdm(enumerate(list_links_articles)):
    d = {"title": [], "released_date":[], "source":[], "url":[],"mentions":[]}
    time.sleep(0.1)
    rep = requests.get(link)
    if rep.status_code == 200:
      page = BeautifulSoup(rep.text, "html.parser")
      d["url"] = link
      d["title"] = page.title.text.split("|")[0]
      source = page.find("p", class_="title-8-bold")
      if source is not None:
        d["source"] = source.text
      date = source.find_next_sibling()
      if date is not None:
        date = date.text.split("·")[1]
      d["released_date"] = datetime.strptime(date, "%d %B %Y").strftime('%d/%m/%Y')
      mentions = [ l.get("aria-label") for l in page.find(string='Mentioned in this article').find_parent().find_parent().find_next_sibling().find_all("a")]
      d["mentions"] = ', '.join(mentions)
      #print(i ," ", d)
      list_infos.append(pd.DataFrame(d, index=[0]))
    else:
      print("Error status code {}".format(rep.status_code))

  return pd.concat(list_infos, ignore_index=True)

# %%
list_articles = set(list_articles)
list_articles.remove('https://onefootball.com/en/competition/premier-league-9')
list_articles = list(list_articles)
list_articles
# Out:
# ['https://onefootball.com/en/news/forest-down-man-utd-villa-leave-it-late-city-palace-chelsea-win-38799472',
#  'https://onefootball.com/en/news/which-premier-league-sides-will-suffer-most-with-afcon-and-asian-cup-call-ups-38815261',
#  'https://onefootball.com/en/news/arsenal-top-this-premier-league-table-that-is-the-mark-of-champions-38798669',
#  'https://onefootball.com/en/news/arsenal-are-keeping-a-keen-eye-on-this-juventus-forward-good-choice-for-arteta-38812588',
#  'https://onefootball.com/en/news/every-starting-budget-at-each-premier-league-club-in-football-manager-2024-38816508',
#  'https://onefootball.com/en/news/frustrated-liverpool-icon-firmino-could-make-pl-return-amid-shock-interest-from-english-club-38796143',
#  'https://onefootball.com/en/news/premier-league-transfer-rumour-mill-vlahovic-a-no-go-for-arsenal-38824753',
#  'https://onefootball.com/en/news/transfer-news-live-chelsea-rival-arsenal-for-toney-onana-move-dragusin-to-tottenham-update-sancho-latest-38803051',
#  'https://onefootball.com/en/news/tottenham-have-asked-about-signing-red-hot-premier-league-striker-whos-already-scored-13-goals-this-season-38822121',
#  'https://onefootball.com/en/news/juventus-insist-arsenal-target-vlahovic-not-for-sale-38824809',
#  'https://onefootball.com/en/news/no-mo-salah-liverpool-look-like-sitting-ducks-for-the-man-city-juggernaut-38820263',
#  'https://onefootball.com/en/news/5-highest-premier-league-xg-after-liverpool-break-record-against-newcastle-38810390',
#  'https://onefootball.com/en/news/jude-bellingham-makes-significant-off-field-change-38816692',
#  'https://onefootball.com/en/news/rodri-on-erling-haaland-he-reminds-me-of-cristiano-and-messi-38805402',
#  'https://onefootball.com/en/news/predicting-the-2023-fifpro-mens-team-of-the-year-38821856',
#  'https://onefootball.com/en/news/arsenal-man-leads-top-10-premier-league-signings-of-the-season-but-spurs-dominate-38821365',
#  'https://onefootball.com/en/news/liverpool-are-discussing-signing-the-best-player-in-the-world-38824935',
#  'https://onefootball.com/en/news/the-worst-premier-league-sales-from-last-summer-38824618',
#  'https://onefootball.com/en/news/20-most-expensive-premier-league-transfers-ever-based-on-inflation-adjusted-fees-38825330',
#  'https://onefootball.com/en/news/fantasy-premier-league-best-replacements-for-salah-and-son-38816264',
#  'https://onefootball.com/en/news/arsenal-learn-the-asking-price-for-23-year-old-attacking-target-38825375',
#  'https://onefootball.com/en/news/why-jesse-lingard-still-doesnt-have-a-new-club-38825489',
#  'https://onefootball.com/en/news/barbora-votikova-nominated-for-player-of-the-month-award-38825464',
#  'https://onefootball.com/en/news/football-transfer-rumours-olise-could-snub-man-utd-arsenal-make-onana-approach-38824978',
#  'https://onefootball.com/en/news/man-utd-reach-amicable-agreement-with-afcon-side-as-player-opts-to-play-two-games-in-24-hours-38817187',
#  'https://onefootball.com/en/news/fa-cup-pressure-spurs-battle-burnley-38825615',
#  'https://onefootball.com/en/news/world-cup-winners-feature-in-six-season-defining-january-loans-by-premier-league-clubs-38808893',
#  'https://onefootball.com/en/news/former-premier-league-goalkeeper-urges-aaron-ramsdale-to-join-manchester-united-38825230',
#  'https://onefootball.com/en/news/60m-man-utd-target-very-much-prefers-move-to-prem-rivals-amid-interest-from-arsenal-liverpool-38822974',
#  'https://onefootball.com/en/news/arsenal-could-benefit-from-juventus-financial-problems-as-cash-plus-player-offer-is-mooted-38814410',
#  'https://onefootball.com/en/news/jurgen-klopp-drops-liverpool-team-news-hint-vs-arsenal-as-injured-dominik-szoboszlai-ruled-out-38825620',
#  'https://onefootball.com/en/news/messi-in-but-ronaldo-snubbed-as-iffhs-team-of-2023-announced-38825503',
#  'https://onefootball.com/en/news/premier-league-reveal-goal-manager-and-player-of-month-nominees-38820385',
#  'https://onefootball.com/en/news/newcastle-could-be-the-next-premier-league-club-to-have-a-spanish-coach-38818902',
#  'https://onefootball.com/en/news/man-city-like-artetas-big-transfer-target-who-is-tipped-for-exit-amid-claim-hes-perfect-for-arsenal-38824570',
#  'https://onefootball.com/en/news/will-still-and-former-premier-league-boss-on-birmingham-citys-radar-38813589',
#  'https://onefootball.com/en/news/kudus-olise-palmer-alexander-arnold-nominated-for-premier-league-potm-award-33482196',
#  'https://onefootball.com/en/news/manchester-united-stance-on-anthony-martial-and-raphael-varane-contracts-38825574',
#  'https://onefootball.com/en/news/the-150-club-premier-leagues-all-time-leading-strikers-as-salah-slides-past-michael-owen-38810121',
#  'https://onefootball.com/en/news/jose-mourinho-teases-that-he-will-look-like-total-idiot-in-new-netflix-documentary-38825506',
#  'https://onefootball.com/en/news/colorado-rapids-sign-goalkeeper-zack-steffen-from-manchester-city-38823120',
#  'https://onefootball.com/en/news/liverpool-fan-favourite-has-been-offered-to-several-premier-league-clubs-38825312',
#  'https://onefootball.com/en/news/jadon-sanchos-loan-to-borussia-dortmund-hits-a-roadblock-38825519',
#  'https://onefootball.com/en/news/liverpools-biggest-splurge-among-every-premier-league-clubs-worst-ever-january-signing-38813982',
#  'https://onefootball.com/en/news/premier-league-clubs-brace-for-ffp-punishment-nottingham-forest-in-hot-seat-38814421',
#  'https://onefootball.com/en/news/tottenham-are-desperate-to-complete-the-signing-of-60m-striker-38825082',
#  'https://onefootball.com/en/news/official-manchester-uniteds-donny-van-de-beek-joins-eintracht-frankfurt-38806943',
#  'https://onefootball.com/en/news/manchester-city-recall-20-year-old-midfield-talent-from-loan-deal-amid-interest-from-premier-league-clubs-38821757',
#  'https://onefootball.com/en/news/big-weekend-arsenal-v-liverpool-howes-no-win-derby-oscar-bobb-maidstone-38824814',
#  'https://onefootball.com/en/news/40m-ace-has-been-watched-several-times-by-man-united-38825374',
#  'https://onefootball.com/en/news/liverpool-legend-linked-with-shock-return-to-premier-league-just-months-after-latest-move-38823442',
#  'https://onefootball.com/en/news/erik-ten-hag-sneaks-into-top-10-premier-league-managers-of-2023-38802971',
#  'https://onefootball.com/en/news/man-utd-newcastle-spurs-among-five-clubs-who-must-take-fa-cup-seriously-38818893',
#  'https://onefootball.com/en/news/kylian-mbappe-misses-playing-with-special-lionel-messi-38820093',
#  'https://onefootball.com/en/news/jurgen-klopp-confirms-dominik-szoboszlai-injury-timeline-38825268',
#  'https://onefootball.com/en/news/manchester-uniteds-transfer-target-could-be-stolen-by-carlo-ancelottis-real-madrid-38825573',
#  'https://onefootball.com/en/news/spurs-vs-burnley-ange-relishing-prospect-of-his-first-fa-cup-tie-38825494',
#  'https://onefootball.com/en/news/transfer-gossip-man-utd-free-to-spend-big-in-january-liverpool-target-prem-winger-38806038',
#  'https://onefootball.com/en/news/ex-liverpool-forward-firmino-linked-with-premier-league-return-38824961',
#  'https://onefootball.com/en/news/tottenham-ange-postecoglou-aware-of-trophy-desire-but-warns-fa-cup-is-not-the-holy-grail-38825619',
#  'https://onefootball.com/en/news/very-unfair-totally-undeserved-boss-cant-get-over-loss-to-newcastle-united-even-months-later-38805316',
#  'https://onefootball.com/en/news/premier-league-mid-season-awards-202324-38794866',
#  'https://onefootball.com/en/news/man-utd-told-to-be-relieved-to-get-5m-back-for-deadweight-whose-agent-deserves-a-slap-38825358',
#  'https://onefootball.com/en/news/liverpool-confirm-dominik-szoboszlai-hamstring-injury-38809350',
#  'https://onefootball.com/en/news/man-city-complete-their-first-transfer-deal-of-the-january-window-38825126',
#  'https://onefootball.com/en/news/study-finds-jude-bellingham-to-be-most-valuable-footballer-three-real-madrid-players-in-top-four-38822930',
#  'https://onefootball.com/en/news/west-ham-0-0-brighton-a-premier-league-nadir-to-end-festive-fixtures-38813030',
#  'https://onefootball.com/en/news/premier-league-club-could-be-punished-after-facing-financial-fair-play-charge-38813663',
#  'https://onefootball.com/en/news/nominees-revealed-for-womens-super-league-december-player-of-the-month-38825560',
#  'https://onefootball.com/en/news/donny-van-de-beek-joins-eintracht-frankfurt-on-loan-from-man-utd-38806416',
#  'https://onefootball.com/en/news/liverpool-give-update-on-dominik-szoboszlai-injury-38825624',
#  'https://onefootball.com/en/news/van-de-beek-makes-tough-man-utd-admission-as-he-highlights-one-positive-from-horror-prem-spell-38825093',
#  'https://onefootball.com/en/news/a-new-years-resolution-for-every-premier-league-club-38806086',
#  'https://onefootball.com/en/news/grading-every-premier-league-clubs-202324-season-so-far-38800027',
#  'https://onefootball.com/en/news/the-15-best-under-21-players-in-the-premier-league-38822575',
#  'https://onefootball.com/en/news/not-had-a-lot-of-coaching-premier-league-legend-criticises-manchester-united-star-38825474',
#  'https://onefootball.com/en/news/jurgen-klopp-drops-liverpool-team-news-hint-vs-arsenal-as-injured-dominik-szoboszlai-ruled-out-38825491',
#  'https://onefootball.com/en/news/tottenham-signing-morgan-gibbs-white-would-be-a-really-nice-move-38823073',
#  'https://onefootball.com/en/news/official-donny-van-de-beek-completes-loan-move-to-eintracht-frankfurt-38806668',
#  'https://onefootball.com/en/news/juergen-klopp-confirms-injury-layoff-for-liverpool-midfielder-38825231',
#  'https://onefootball.com/en/news/i-said-if-i-wish-them-good-luck-it-would-be-a-lie-liverpool-boss-klopp-reacts-to-salah-endo-absence-38825626',
#  'https://onefootball.com/en/news/5-big-questions-ahead-of-the-premier-league-weekend-38798413',
#  'https://onefootball.com/en/news/transfer-news-live-arsenal-make-onana-move-chelsea-plot-vlahovic-bid-dragusin-to-tottenham-update-sancho-38824396',
#  'https://onefootball.com/en/news/transfer-news-live-arsenal-learn-new-toney-option-new-defender-targets-dragusin-to-spurs-chelsea-latest-38818826',
#  'https://onefootball.com/en/news/the-debrief-after-the-last-premier-league-saturday-of-2023-38800838',
#  'https://onefootball.com/en/news/why-tottenham-trump-arsenal-and-chelsea-with-january-transfer-spending-power-38822170',
#  'https://onefootball.com/en/news/transfer-news-live-arsenal-have-zubimendi-plan-chelsea-confirm-deal-man-utd-get-werner-boost-sancho-spurs-38798848',
#  'https://onefootball.com/en/news/man-united-are-keen-on-signing-the-next-moises-caicedo-38824982',
#  'https://onefootball.com/en/news/eintracht-frankfurt-reach-agreement-with-aurele-amenda-over-a-transfer-38822532',
#  'https://onefootball.com/en/news/donny-van-de-beek-leaves-man-utd-for-the-bundesliga-38806351']

# %%
table_articles_one_football = table_news_articles_one_football(list_articles)
table_articles_one_football
# Out:
# 90it [00:45,  1.97it/s]
#                                                 title released_date  \
# 0   🦁 Forest down Man Utd; Villa leave it late; Ci...    30/12/2023
# 1   Which Premier League sides will suffer most wi...    03/01/2024
# 2   Arsenal top this Premier League table that is ...    30/12/2023
# 3   Arsenal Are Keeping A Keen Eye On This Juventu...    02/01/2024
# 4   Every starting budget at each Premier League c...    03/01/2024
# ..                                                ...           ...
# 85  Why Tottenham trump Arsenal and Chelsea with J...    04/01/2024
# 86  Transfer news LIVE! Arsenal have Zubimendi pla...    30/12/2023
# 87  Man United are keen on signing ‘the next Moise...    05/01/2024
# 88  Eintracht Frankfurt reach agreement with Aurèl...    04/01/2024
# 89  Donny van de Beek leaves Man Utd for the Bunde...    01/01/2024
#
#                       source  \
# 0                OneFootball
# 1            The Independent
# 2                Football365
# 3           The 4th Official
# 4                GiveMeSport
# ..                       ...
# 85          Evening Standard
# 86          Evening Standard
# 87             caughtoffside
# 88  Get German Football News
# 89               OneFootball
#
#                                                   url  \
# 0   https://onefootball.com/en/news/forest-down-ma...
# 1   https://onefootball.com/en/news/which-premier-...
# 2   https://onefootball.com/en/news/arsenal-top-th...
# 3   https://onefootball.com/en/news/arsenal-are-ke...
# 4   https://onefootball.com/en/news/every-starting...
# ..                                                ...
# 85  https://onefootball.com/en/news/why-tottenham-...
# 86  https://onefootball.com/en/news/transfer-news-...
# 87  https://onefootball.com/en/news/man-united-are...
# 88  https://onefootball.com/en/news/eintracht-fran...
# 89  https://onefootball.com/en/news/donny-van-de-b...
#
#                                              mentions
# 0   Burnley, Manchester United, Manchester City, C...
# 1   Liverpool, Tottenham Hotspur, Manchester Unite...
# 2   Arsenal, Manchester City, Brighton & Hove Albi...
# 3                   Juventus, Arsenal, Dušan Vlahović
# 4               Premier League, UEFA Champions League
# ..                                                ...
# 85  Chelsea, Arsenal, Tottenham Hotspur, Premier L...
# 86  Chelsea, Arsenal, Tottenham Hotspur, Mancheste...
# 87  Manchester United, Brighton & Hove Albion, Pre...
# 88  Manchester United, Eintracht Frankfurt, Donny ...
# 89  Manchester United, Eintracht Frankfurt, Donny ...
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Articles from BBC sports

# %%
def get_news_link_bbc(link):
  """
  extract news links from a BBC sport webpage
  """
  rep = requests.get(link)
  pattern = r"/sport/football/\d+"
  if rep.status_code == 200:
    soup = BeautifulSoup(rep.text, 'html.parser')
    web_links = soup.find_all('a')
    actual_web_links = [re.search(pattern,str(web_link['href']))[0]  for web_link in web_links if re.search(pattern, str(web_link))]
    return set(actual_web_links)

# %%
list_articles_bbc = get_news_links_bfs(starting_url ="https://www.bbc.com/sport/football/premier-league" , website_path="https://www.bbc.com" ,link_extractor = get_news_link_bbc ,max_nb = 1000)
# Out:
# nb visited articles :  10
# nb visited articles :  20
# nb visited articles :  30
# nb visited articles :  40
# nb visited articles :  40
# nb visited articles :  50
# nb visited articles :  50
# nb visited articles :  50
# nb visited articles :  50
# nb visited articles :  50
# nb visited articles :  60
# nb visited articles :  60
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70
# nb visited articles :  70

# %%
import datetime

def get_news_table_bbc(list_articles_bbc):
  list_infos = []
  for link in tqdm(list_articles_bbc):
    d = {}
    time.sleep(0.1)
    rep = requests.get(link)
    if rep.status_code == 200:
      soup = BeautifulSoup(rep.text, 'html.parser')
      # Find the <meta> element with property="og:title"
      og_title_meta = soup.find('meta', {'property': 'og:title'})
      # Print the content attribute of the found element
      if og_title_meta:
        d["title"] = og_title_meta.get('content')
      #soup.find("time").get_text(separator="|"))
      s = soup.find("time")
      if s is None:
        date = s.get("datetime").split("T")[0]

        d["released_date"] = datetime.datetime.strptime(date, "%Y-%m-%d").strftime("%d/%m/%Y")
        d["source"] = "BBC Sport"
        d["url"] = link
        css_selector = 'a[href^="/sport/football/"]'
        d["mentions"] = [l.text for l in soup.select(css_selector)][0]

      list_infos.append(pd.DataFrame(d, index=[0]))
    else:
      print("Error status code {}".format(rep.status_code))

  return pd.concat(list_infos, ignore_index=True)

# %%
list_articles_bbc = set(list_articles_bbc)
list_articles_bbc.remove("https://www.bbc.com/sport/football/premier-league")
list_articles_bbc = list(list_articles_bbc)
table_bbc = get_news_table_bbc(list_articles_bbc)
table_bbc
# Out:
#  41%|████▏     | 31/75 [00:13<00:19,  2.30it/s]
# Error status code 404
# 100%|██████████| 75/75 [00:32<00:00,  2.28it/s]
#                                                 title released_date  \
# 0   Fulham's Silva charged by FA after referee com...    04/01/2024
# 1    Wan-Bissaka one of three to extend Man Utd deals    04/01/2024
# 2     Who was 'outstanding'? Garth's Team of the Week    02/01/2024
# 3               Follow Liverpool in the BBC Sport app    05/01/2024
# 4   Referee couldn't handle pressure, says angry S...    16/12/2023
# ..                                                ...           ...
# 69   Follow your club and get news sent direct to you    05/01/2024
# 70  Luton's Lockyer still in hospital after collap...    17/12/2023
# 71                           Have your say on Man Utd    04/01/2024
# 72  Reguilon returns to Spurs as Man Utd end loan ...    02/01/2024
# 73  Maidstone stun Barrow to reach FA Cup third round    02/12/2023
#
#        source                                          url            mentions
# 0   BBC Sport  https://www.bbc.com/sport/football/67886178             Fulham
# 1   BBC Sport  https://www.bbc.com/sport/football/67879910  Manchester United
# 2   BBC Sport  https://www.bbc.com/sport/football/67865895     Premier League
# 3   BBC Sport  https://www.bbc.com/sport/football/62289316          Liverpool
# 4   BBC Sport  https://www.bbc.com/sport/football/67739716     Premier League
# ..        ...                                          ...                 ...
# 69  BBC Sport  https://www.bbc.com/sport/football/66302372     Premier League
# 70  BBC Sport  https://www.bbc.com/sport/football/67744280         Luton Town
# 71  BBC Sport  https://www.bbc.com/sport/football/59821410  Manchester United
# 72  BBC Sport  https://www.bbc.com/sport/football/67864491     Premier League
# 73  BBC Sport  https://www.bbc.com/sport/football/67579275         The FA Cup
#
# [74 rows x 5 columns]

# %%
table_articles_premier_league =  pd.concat([table_articles_one_football,table_bbc], ignore_index=True)

# %%
table_articles_premier_league
# Out:
#                                                  title released_date  \
# 0    🦁 Forest down Man Utd; Villa leave it late; Ci...    30/12/2023
# 1    Which Premier League sides will suffer most wi...    03/01/2024
# 2    Arsenal top this Premier League table that is ...    30/12/2023
# 3    Arsenal Are Keeping A Keen Eye On This Juventu...    02/01/2024
# 4    Every starting budget at each Premier League c...    03/01/2024
# ..                                                 ...           ...
# 159   Follow your club and get news sent direct to you    05/01/2024
# 160  Luton's Lockyer still in hospital after collap...    17/12/2023
# 161                           Have your say on Man Utd    04/01/2024
# 162  Reguilon returns to Spurs as Man Utd end loan ...    02/01/2024
# 163  Maidstone stun Barrow to reach FA Cup third round    02/12/2023
#
#                source                                                url  \
# 0         OneFootball  https://onefootball.com/en/news/forest-down-ma...
# 1     The Independent  https://onefootball.com/en/news/which-premier-...
# 2         Football365  https://onefootball.com/en/news/arsenal-top-th...
# 3    The 4th Official  https://onefootball.com/en/news/arsenal-are-ke...
# 4         GiveMeSport  https://onefootball.com/en/news/every-starting...
# ..                ...                                                ...
# 159         BBC Sport        https://www.bbc.com/sport/football/66302372
# 160         BBC Sport        https://www.bbc.com/sport/football/67744280
# 161         BBC Sport        https://www.bbc.com/sport/football/59821410
# 162         BBC Sport        https://www.bbc.com/sport/football/67864491
# 163         BBC Sport        https://www.bbc.com/sport/football/67579275
#
#                                               mentions
# 0    Burnley, Manchester United, Manchester City, C...
# 1    Liverpool, Tottenham Hotspur, Manchester Unite...
# 2    Arsenal, Manchester City, Brighton & Hove Albi...
# 3                    Juventus, Arsenal, Dušan Vlahović
# 4                Premier League, UEFA Champions League
# ..                                                 ...
# 159                                    Premier League
# 160                                        Luton Town
# 161                                 Manchester United
# 162                                    Premier League
# 163                                        The FA Cup
#
# [164 rows x 5 columns]

# %%
import os 
current = os.getcwd() #get the path of current directory
parent_directory = os.path.dirname(current) 
table_articles_premier_league.to_csv(parent_directory + "/data/articles_premier_leagues.csv")

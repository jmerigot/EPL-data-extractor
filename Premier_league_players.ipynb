# %%
import requests
import json
import pandas as pd
import numpy as np
import bs4
import re
import time
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# # Premier League Football Players' Data Extraction
#
# Extracting all information and statistics from the One Football website, which can be found here: https://onefootball.com/en/home
#
# We are focusing on the Premier League and scraping the website using `BeautifulSoup` in order to obtain data on the matches played during the current 2023-24 season as well as the performance statistics and general information about the players of all teams involved.
#
# The below code blocks work to extract all important information and statistics about the football players of each team in the Premier League. This is done by first collecting the href links of all teams in the premier league, then collecting all players hrefs to collect their info, and finally collecting all basic information about the players and collecting all their statistics in two seperate pandas dataframes, before merging the two into one final panda dataframe that will be our dataset.

# %%
def get_player_links(base_url):
    response = requests.get(base_url)
    team_links = []
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        team_link_tags = soup.find_all('a', class_='Standing_standings__rowGrid__45OOd')

        for tag in team_link_tags:
            team_name_tag = tag.find('p', class_='Standing_standings__teamName__psv61')
            if team_name_tag:
                team_links.append(tag['href'])

        return team_links
    else:
        return None

# collecting the href links of all teams in the premier league
team_urls = []

base_url = "https://onefootball.com/en/competition/premier-league-9/table"
while len(team_urls) < 20:
    time.sleep(0.1)
    df = get_player_links(base_url)
    if df is not None:
        team_urls.extend(df)

# add '/squad' to href link in order to collect all players
team_urls_squad = team_urls.copy()
for i in range(len(team_urls_squad)):
  team_urls_squad[i] += '/squad'
print(team_urls_squad)
# Out:
# ['/en/team/liverpool-18/squad', '/en/team/aston-villa-199/squad', '/en/team/manchester-city-209/squad', '/en/team/arsenal-2/squad', '/en/team/tottenham-hotspur-202/squad', '/en/team/west-ham-united-198/squad', '/en/team/brighton-hove-albion-670/squad', '/en/team/manchester-united-21/squad', '/en/team/newcastle-united-207/squad', '/en/team/chelsea-9/squad', '/en/team/wolverhampton-wanderers-203/squad', '/en/team/afc-bournemouth-622/squad', '/en/team/fulham-211/squad', '/en/team/crystal-palace-567/squad', '/en/team/nottingham-forest-577/squad', '/en/team/brentford-671/squad', '/en/team/everton-197/squad', '/en/team/luton-town-599/squad', '/en/team/burnley-275/squad', '/en/team/sheffield-united-583/squad']

# %%
def get_player_links(base_url, id_team):
    response = requests.get(base_url + id_team)
    player_links = []
    if response.status_code == 200:
        #print("Processing team: ", id_team)
        soup = BeautifulSoup(response.text, "html.parser")

        script_tag = soup.find('script', {'id': '__NEXT_DATA__'})

        if script_tag:
            data = json.loads(script_tag.string)

            goalkeeper = data['props']['pageProps']['containers'][3]['type']['fullWidth']['component']['contentType']['entityNavigation']['links']
            keeper = [player['urlPath'] for player in goalkeeper]

            defenders = data['props']['pageProps']['containers'][4]['type']['fullWidth']['component']['contentType']['entityNavigation']['links']
            defender = [player['urlPath'] for player in defenders]

            midfeilders = data['props']['pageProps']['containers'][6]['type']['fullWidth']['component']['contentType']['entityNavigation']['links']
            midfield = [player['urlPath'] for player in midfeilders]

            forwards = data['props']['pageProps']['containers'][7]['type']['fullWidth']['component']['contentType']['entityNavigation']['links']
            forward = [player['urlPath'] for player in forwards]

            return keeper + defender + midfield + forward
    else:
        print(f"Failed to retrieve the team page. Status code: {response.status_code}")
        return None

# collecting all players hrefs to collect their info
player_urls = []

base_url = "https://onefootball.com"
for team in tqdm(team_urls_squad):
  time.sleep(0.1)
  df = get_player_links(base_url, str(team))
  if df is not None:
    player_urls.extend(df)

# add '/stats' to href link in order to collect all stats of players
player_urls_stats = player_urls.copy()
for i in range(len(player_urls_stats)):
  player_urls_stats[i] += '/stats'
print(player_urls_stats)
# Out:
# 100%|██████████| 20/20 [00:09<00:00,  2.10it/s]
# ['/en/player/adrian-30947/stats', '/en/player/alisson-44430/stats', '/en/player/caoimhin-kelleher-262070/stats', '/en/player/fabian-mrozek-454565/stats', '/en/player/marcelo-pitaluga-247112/stats', '/en/player/vitezslav-jaros-322809/stats', '/en/player/andrew-robertson-50472/stats', '/en/player/calum-scanlon-454578/stats', '/en/player/conor-bradley-364237/stats', '/en/player/ibrahima-konate-200826/stats', '/en/player/jarell-quansah-364445/stats', '/en/player/joe-gomez-74328/stats', '/en/player/joel-matip-1179/stats', '/en/player/kostas-tsimikas-107857/stats', '/en/player/luke-chambers-451222/stats', '/en/player/trent-alexander-arnold-187991/stats', '/en/player/virgil-van-dijk-31292/stats', '/en/player/alexis-mac-allister-219345/stats', '/en/player/bobby-clark-454564/stats', '/en/player/curtis-jones-254380/stats', '/en/player/dominik-szoboszlai-208602/stats', '/en/player/harvey-elliott-272821/stats', '/en/player/james-mcconnell-451221/stats', '/en/player/ryan-gravenberch-260384/stats', '/en/player/stefan-bajcetic-454574/stats', '/en/player/thiago-149/stats', '/en/player/thomas-hill-358894/stats', '/en/player/treymaurice-nyoni-520804/stats', '/en/player/wataru-endo-47589/stats', '/en/player/ben-doak-468026/stats', '/en/player/cody-gakpo-197282/stats', '/en/player/darwin-nunez-253172/stats', '/en/player/diogo-jota-78417/stats', '/en/player/kaide-gordon-420369/stats', '/en/player/lewis-koumas-454579/stats', '/en/player/luis-diaz-208859/stats', '/en/player/mohamed-salah-27382/stats', '/en/player/emiliano-martinez-20292/stats', '/en/player/filip-marschall-354895/stats', '/en/player/robin-olsen-25023/stats', '/en/player/sam-proctor-520412/stats', '/en/player/alex-moreno-50753/stats', '/en/player/calum-chambers-31228/stats', '/en/player/clement-lenglet-56928/stats', '/en/player/diego-carlos-50686/stats', '/en/player/ezri-konsa-173170/stats', '/en/player/josh-feeney-431521/stats', '/en/player/kortney-hause-33374/stats', '/en/player/lucas-digne-23845/stats', '/en/player/matty-cash-178444/stats', '/en/player/pau-torres-199280/stats', '/en/player/tyrone-mings-40197/stats', '/en/player/bertrand-traore-24456/stats', '/en/player/boubacar-kamara-199018/stats', '/en/player/douglas-luiz-205388/stats', '/en/player/emiliano-buendia-101888/stats', '/en/player/jacob-ramsey-307924/stats', '/en/player/john-mcginn-32317/stats', '/en/player/leander-dendoncker-41907/stats', '/en/player/leon-bailey-160355/stats', '/en/player/nicolo-zaniolo-199977/stats', '/en/player/omari-kellyman-464116/stats', '/en/player/tim-iroegbunam-416417/stats', '/en/player/tommi-oreilly-451285/stats', '/en/player/travis-patterson-458766/stats', '/en/player/youri-tielemans-52288/stats', '/en/player/caleb-chukwuemeka-382927/stats', '/en/player/jhon-duran-306842/stats', '/en/player/kadan-young-519539/stats', '/en/player/moussa-diaby-230488/stats', '/en/player/ollie-watkins-62150/stats', '/en/player/ederson-32233/stats', '/en/player/scott-carson-2230/stats', '/en/player/stefan-ortega-16940/stats', '/en/player/true-grant-454474/stats', '/en/player/zack-steffen-189511/stats', '/en/player/john-stones-29186/stats', '/en/player/josko-gvardiol-301987/stats', '/en/player/kyle-walker-3147/stats', '/en/player/manuel-akanji-104090/stats', '/en/player/max-alleyne-495224/stats', '/en/player/nathan-ake-40052/stats', '/en/player/rico-lewis-449606/stats', '/en/player/ruben-dias-112460/stats', '/en/player/bernardo-silva-63999/stats', '/en/player/jack-grealish-31186/stats', '/en/player/kalvin-phillips-107504/stats', '/en/player/kevin-de-bruyne-9720/stats', '/en/player/mahamadou-susoho-454477/stats', '/en/player/mateo-kovacic-18433/stats', '/en/player/matheus-nunes-266816/stats', '/en/player/micah-hamilton-416340/stats', '/en/player/oscar-bobb-364212/stats', '/en/player/phil-foden-198803/stats', '/en/player/rodri-173112/stats', '/en/player/sergio-gomez-238296/stats', '/en/player/erling-haaland-181353/stats', '/en/player/julian-alvarez-266511/stats', '/en/player/jeremy-doku-292404/stats', '/en/player/ ...

# %%
def get_player_stats(base_url, id_player):
    stats = {"Name": None, "Team": None}
    rep = requests.get(base_url + id_player)
    if rep.status_code == 200:
        #print("id player : ", id_player)
        soup = BeautifulSoup(rep.text, "html.parser")

        # player name
        stats["Name"] = soup.title.string.split(' Profile | OneFootball')[0]

        # player team
        script_tag = soup.find('script', {'type': 'application/ld+json'})
        data = json.loads(script_tag.string)
        stats["Team"] = data['affiliation']['name']

        # player stats
        desired_headers = ["KEY STATS"]
        potential_stats_divs = soup.find_all('div', class_='transfer-details')

        for div in potential_stats_divs:
            header = div.find('p', class_='transfer-details__header',
                              string=lambda string: any(header in string for header in desired_headers))
            if header:
                for entry in div.find_all('li', class_='transfer-details-list__entry'):
                    value = entry.find('p', class_='title-3-bold').text.strip()
                    stat_name = entry.find('p', class_='title-7-regular').text.strip()
                    stats[stat_name] = value

        return pd.DataFrame(stats, index=[0])
    else:
        return None

# collecting basic information
list_results_info = []

base_url = "https://onefootball.com/"
for player in tqdm(player_urls):
  time.sleep(0.1)
  df = get_player_stats(base_url, str(player))
  if df is not None:
    list_results_info.append(df)

table_info = pd.concat(list_results_info, ignore_index=True)
table_info
# Out:
# 100%|██████████| 664/664 [05:45<00:00,  1.92it/s]
#                   Name              Team Age    Position   Country  Height  \
# 0               Adrian         Liverpool  37  Goalkeeper     Spain  190 cm
# 1              Alisson         Liverpool  31  Goalkeeper    Brazil  193 cm
# 2    Caoimhín Kelleher         Liverpool  25  Goalkeeper   Ireland  188 cm
# 3        Fabian Mrozek         Liverpool  20  Goalkeeper    Poland  192 cm
# 4     Marcelo Pitaluga         Liverpool  21  Goalkeeper    Brazil  192 cm
# ..                 ...               ...  ..         ...       ...     ...
# 659    Daniel Jebbison  Sheffield United  20     Forward    Canada  190 cm
# 660    Oliver McBurnie  Sheffield United  27     Forward  Scotland  188 cm
# 661     Rhian Brewster  Sheffield United  23     Forward   England  180 cm
# 662           Ryan Oné  Sheffield United  17     Forward  Scotland    0 cm
# 663      William Osula  Sheffield United  20     Forward   Denmark  180 cm
#
#     Weight Jersey number
# 0    80 kg            13
# 1    91 kg             1
# 2    74 kg            62
# 3     0 kg            93
# 4    77 kg            45
# ..     ...           ...
# 659  69 kg            36
# 660  79 kg             9
# 661  75 kg             7
# 662   0 kg            26
# 663  81 kg            32
#
# [664 rows x 8 columns]

# %%
def get_player_stats(base_url, id_player):
    stats = {"Name": None, "Team": None}
    rep = requests.get(base_url + id_player)
    if rep.status_code == 200:
        #print("id player : ", id_player)
        soup = BeautifulSoup(rep.text, "html.parser")

        # player name
        stats["Name"] = soup.title.string.split(' Season Stats |')[0]

        # player team
        script_tag = soup.find('script', {'type': 'application/ld+json'})
        data = json.loads(script_tag.string)
        stats["Team"] = data['affiliation']['name']

        # player stats
        desired_headers = ["KEY STATS", "DEFENCE", "DISTRIBUTION", "OFFENSE", "DISCIPLINE"]
        potential_stats_divs = soup.find_all('div', class_='transfer-details')

        for div in potential_stats_divs:
            header = div.find('p', class_='transfer-details__header',
                              string=lambda string: any(header in string for header in desired_headers))
            if header:
                for entry in div.find_all('li', class_='transfer-details-list__entry'):
                    value = entry.find('p', class_='title-3-bold').text.strip()
                    stat_name = entry.find('p', class_='title-7-regular').text.strip()
                    full_stat_name = f"{header.text.strip()}_{stat_name}"
                    stats[full_stat_name] = value

        return pd.DataFrame(stats, index=[0])
    else:
        return None

# collecting all player statistics
list_results_stats = []

base_url = "https://onefootball.com/"
for player in tqdm(player_urls_stats):
  time.sleep(0.1)
  df = get_player_stats(base_url, str(player))
  if df is not None:
    list_results_stats.append(df)

table_stats = pd.concat(list_results_stats, ignore_index=True)
table_stats
# Out:
# 100%|██████████| 664/664 [06:00<00:00,  1.84it/s]
#                   Name              Team KEY STATS_Goals KEY STATS_Assists  \
# 0               Adrian         Liverpool               0                 0
# 1              Alisson         Liverpool               0                 0
# 2    Caoimhín Kelleher         Liverpool               0                 0
# 3        Fabian Mrozek         Liverpool             NaN               NaN
# 4     Marcelo Pitaluga         Liverpool               0                 0
# ..                 ...               ...             ...               ...
# 659    Daniel Jebbison  Sheffield United             NaN               NaN
# 660    Oliver McBurnie  Sheffield United               3                 1
# 661     Rhian Brewster  Sheffield United               0                 0
# 662           Ryan Oné  Sheffield United               0                 0
# 663      William Osula  Sheffield United               0                 0
#
#     KEY STATS_Shot Accuracy KEY STATS_Pass Accuracy DEFENCE_Tackles  \
# 0                      0.00                     0.0               0
# 1                      0.00                    84.1               0
# 2                      0.00                    91.0               0
# 3                       NaN                     NaN             NaN
# 4                      0.00                     0.0               0
# ..                      ...                     ...             ...
# 659                     NaN                     NaN             NaN
# 660                   64.29                    58.0               9
# 661                  100.00                    67.4               4
# 662                    0.00                   100.0               0
# 663                   55.56                    45.9               1
#
#     DEFENCE_Tackles Won DEFENCE_Duels DEFENCE_Duels won  ...  \
# 0                   0.0             0            0.00 %  ...
# 1                   0.0            11           72.73 %  ...
# 2                   0.0             1          100.00 %  ...
# 3                   NaN           NaN               NaN  ...
# 4                   0.0             0            0.00 %  ...
# ..                  ...           ...               ...  ...
# 659                 NaN           NaN               NaN  ...
# 660                22.2           183           48.63 %  ...
# 661                25.0            19           36.84 %  ...
# 662                 0.0             0            0.00 %  ...
# 663               100.0            99           27.27 %  ...
#
#     OFFENSE_Goals - inside the box OFFENSE_Goals - outside the box  \
# 0                                0                               0
# 1                                0                               0
# 2                                0                               0
# 3                              NaN                             NaN
# 4                                0                               0
# ..                             ...                             ...
# 659                            NaN                             NaN
# 660                              3                               0
# 661                              0                               0
# 662                              0                               0
# 663                              0                               0
#
#     OFFENSE_Other goals OFFENSE_Successful dribbles OFFENSE_Offsides  \
# 0                     0                           0                0
# 1                     0                           0                0
# 2                     0                           0                0
# 3                   NaN                         NaN              NaN
# 4                     0                           0                0
# ..                  ...                         ...              ...
# 659                 NaN                         NaN              NaN
# 660                   0                           4                4
# 661                   0                           0                0
# 662                   0                           0                0
# 663                   0                           2                5
#
#     DISCIPLINE_Yellow cards DISCIPLINE_Yellow - red cards  \
# 0                         0                             0
# 1                         1                             0
# 2                         0                             0
# 3                       NaN                           NaN
# 4                         0                             0
# ..                      ...                           ...
# 659                     NaN                           NaN
# 660                       1                             2
# 661                       0                             0
# 662                       0                             0
# 663                       4                             0
#
#     DISCIPLINE_Red cards DISCIPLINE_Fouls conceded DISCIPLINE_Fouls won
# 0                      0                         0                    0
# 1                      0                         1                    4
# 2                      0                         0                    0
# 3                    NaN                       NaN                  NaN
# 4                      0                         0                    0
# ..                   ...                       ...                  ...
# 659                  NaN                       NaN                  NaN
# 660                    2                        12                   17
# 661                    0                         2                    1
# 662                    0                         0                    0
# 663                    0                        10                    7
#
# [664 rows x 37 columns]

# %%
# merge both tables together
merged_stats = table_info.merge(table_stats, on=['Name', 'Team'], how='inner')
merged_stats
# Out:
#                   Name              Team Age    Position   Country  Height  \
# 0               Adrian         Liverpool  37  Goalkeeper     Spain  190 cm
# 1              Alisson         Liverpool  31  Goalkeeper    Brazil  193 cm
# 2    Caoimhín Kelleher         Liverpool  25  Goalkeeper   Ireland  188 cm
# 3        Fabian Mrozek         Liverpool  20  Goalkeeper    Poland  192 cm
# 4     Marcelo Pitaluga         Liverpool  21  Goalkeeper    Brazil  192 cm
# ..                 ...               ...  ..         ...       ...     ...
# 661    Daniel Jebbison  Sheffield United  20     Forward    Canada  190 cm
# 662    Oliver McBurnie  Sheffield United  27     Forward  Scotland  188 cm
# 663     Rhian Brewster  Sheffield United  23     Forward   England  180 cm
# 664           Ryan Oné  Sheffield United  17     Forward  Scotland    0 cm
# 665      William Osula  Sheffield United  20     Forward   Denmark  180 cm
#
#     Weight Jersey number KEY STATS_Goals KEY STATS_Assists  ...  \
# 0    80 kg            13               0                 0  ...
# 1    91 kg             1               0                 0  ...
# 2    74 kg            62               0                 0  ...
# 3     0 kg            93             NaN               NaN  ...
# 4    77 kg            45               0                 0  ...
# ..     ...           ...             ...               ...  ...
# 661  69 kg            36             NaN               NaN  ...
# 662  79 kg             9               3                 1  ...
# 663  75 kg             7               0                 0  ...
# 664   0 kg            26               0                 0  ...
# 665  81 kg            32               0                 0  ...
#
#     OFFENSE_Goals - inside the box OFFENSE_Goals - outside the box  \
# 0                                0                               0
# 1                                0                               0
# 2                                0                               0
# 3                              NaN                             NaN
# 4                                0                               0
# ..                             ...                             ...
# 661                            NaN                             NaN
# 662                              3                               0
# 663                              0                               0
# 664                              0                               0
# 665                              0                               0
#
#     OFFENSE_Other goals OFFENSE_Successful dribbles OFFENSE_Offsides  \
# 0                     0                           0                0
# 1                     0                           0                0
# 2                     0                           0                0
# 3                   NaN                         NaN              NaN
# 4                     0                           0                0
# ..                  ...                         ...              ...
# 661                 NaN                         NaN              NaN
# 662                   0                           4                4
# 663                   0                           0                0
# 664                   0                           0                0
# 665                   0                           2                5
#
#     DISCIPLINE_Yellow cards DISCIPLINE_Yellow - red cards  \
# 0                         0                             0
# 1                         1                             0
# 2                         0                             0
# 3                       NaN                           NaN
# 4                         0                             0
# ..                      ...                           ...
# 661                     NaN                           NaN
# 662                       1                             2
# 663                       0                             0
# 664                       0                             0
# 665                       4                             0
#
#     DISCIPLINE_Red cards DISCIPLINE_Fouls conceded DISCIPLINE_Fouls won
# 0                      0                         0                    0
# 1                      0                         1                    4
# 2                      0                         0                    0
# 3                    NaN                       NaN                  NaN
# 4                      0                         0                    0
# ..                   ...                       ...                  ...
# 661                  NaN                       NaN                  NaN
# 662                    2                        12                   17
# 663                    0                         2                    1
# 664                    0                         0                    0
# 665                    0                        10                    7
#
# [666 rows x 43 columns]

# %%
# clean dataset column names to make more presentable

def clean_column_names(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(' ', '_')
    return df

all_stats = clean_column_names(merged_stats)
all_stats
# Out:
#                   name              team age    position   country  height  \
# 0               Adrian         Liverpool  37  Goalkeeper     Spain  190 cm
# 1              Alisson         Liverpool  31  Goalkeeper    Brazil  193 cm
# 2    Caoimhín Kelleher         Liverpool  25  Goalkeeper   Ireland  188 cm
# 3        Fabian Mrozek         Liverpool  20  Goalkeeper    Poland  192 cm
# 4     Marcelo Pitaluga         Liverpool  21  Goalkeeper    Brazil  192 cm
# ..                 ...               ...  ..         ...       ...     ...
# 661    Daniel Jebbison  Sheffield United  20     Forward    Canada  190 cm
# 662    Oliver McBurnie  Sheffield United  27     Forward  Scotland  188 cm
# 663     Rhian Brewster  Sheffield United  23     Forward   England  180 cm
# 664           Ryan Oné  Sheffield United  17     Forward  Scotland    0 cm
# 665      William Osula  Sheffield United  20     Forward   Denmark  180 cm
#
#     weight jersey_number key_stats_goals key_stats_assists  ...  \
# 0    80 kg            13               0                 0  ...
# 1    91 kg             1               0                 0  ...
# 2    74 kg            62               0                 0  ...
# 3     0 kg            93             NaN               NaN  ...
# 4    77 kg            45               0                 0  ...
# ..     ...           ...             ...               ...  ...
# 661  69 kg            36             NaN               NaN  ...
# 662  79 kg             9               3                 1  ...
# 663  75 kg             7               0                 0  ...
# 664   0 kg            26               0                 0  ...
# 665  81 kg            32               0                 0  ...
#
#     offense_goals_-_inside_the_box offense_goals_-_outside_the_box  \
# 0                                0                               0
# 1                                0                               0
# 2                                0                               0
# 3                              NaN                             NaN
# 4                                0                               0
# ..                             ...                             ...
# 661                            NaN                             NaN
# 662                              3                               0
# 663                              0                               0
# 664                              0                               0
# 665                              0                               0
#
#     offense_other_goals offense_successful_dribbles offense_offsides  \
# 0                     0                           0                0
# 1                     0                           0                0
# 2                     0                           0                0
# 3                   NaN                         NaN              NaN
# 4                     0                           0                0
# ..                  ...                         ...              ...
# 661                 NaN                         NaN              NaN
# 662                   0                           4                4
# 663                   0                           0                0
# 664                   0                           0                0
# 665                   0                           2                5
#
#     discipline_yellow_cards discipline_yellow_-_red_cards  \
# 0                         0                             0
# 1                         1                             0
# 2                         0                             0
# 3                       NaN                           NaN
# 4                         0                             0
# ..                      ...                           ...
# 661                     NaN                           NaN
# 662                       1                             2
# 663                       0                             0
# 664                       0                             0
# 665                       4                             0
#
#     discipline_red_cards discipline_fouls_conceded discipline_fouls_won
# 0                      0                         0                    0
# 1                      0                         1                    4
# 2                      0                         0                    0
# 3                    NaN                       NaN                  NaN
# 4                      0                         0                    0
# ..                   ...                       ...                  ...
# 661                  NaN                       NaN                  NaN
# 662                    2                        12                   17
# 663                    0                         2                    1
# 664                    0                         0                    0
# 665                    0                        10                    7
#
# [666 rows x 43 columns]
